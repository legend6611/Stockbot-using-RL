# %%
import tensorflow as tf

# In TensorFlow 2.x, eager execution is enabled by default, so no need for tf.enable_eager_execution()
print("Eager execution is enabled:", tf.executing_eagerly())
# !pip install stable_baselines3
# Out:
# Eager execution is enabled: True
# Collecting stable_baselines3
#   Downloading stable_baselines3-2.6.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (1.1.1)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.0.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.6.0+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable_baselines3) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch<3.0,>=2.3->stable_baselines3)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable_baselines3) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable_baselines3) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3) (3.0.2)
# Downloading stable_baselines3-2.6.0-py3-none-any.whl (184 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.5/184.5 kB 3.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 23.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 21.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 19.0 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.1 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.2 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, stable_baselines3
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 stable_baselines3-2.6.0

# %%
# !pip install gym_anytrading
# Out:
# Collecting gym_anytrading
#   Downloading gym_anytrading-2.0.0-py3-none-any.whl.metadata (292 bytes)
# Requirement already satisfied: gymnasium>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from gym_anytrading) (1.1.1)
# Requirement already satisfied: numpy>=1.16.4 in /usr/local/lib/python3.11/dist-packages (from gym_anytrading) (2.0.2)
# Requirement already satisfied: pandas>=0.24.2 in /usr/local/lib/python3.11/dist-packages (from gym_anytrading) (2.2.2)
# Requirement already satisfied: matplotlib>=3.1.1 in /usr/local/lib/python3.11/dist-packages (from gym_anytrading) (3.10.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.29.1->gym_anytrading) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.29.1->gym_anytrading) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=0.29.1->gym_anytrading) (0.0.4)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym_anytrading) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym_anytrading) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym_anytrading) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym_anytrading) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym_anytrading) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym_anytrading) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym_anytrading) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=3.1.1->gym_anytrading) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->gym_anytrading) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24.2->gym_anytrading) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=3.1.1->gym_anytrading) (1.17.0)
# Downloading gym_anytrading-2.0.0-py3-none-any.whl (172 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.2/172.2 kB 3.3 MB/s eta 0:00:00
# Installing collected packages: gym_anytrading
# Successfully installed gym_anytrading-2.0.0

# %%
# Ensure compatibility with Stable-Baselines3
from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
import gymnasium as gym
import gym_anytrading
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
# !mkdir data

# %%
# Load dataset
df = pd.read_csv(r"/content/combined_dataset.csv")
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# %%
df.head()
# Out:
#                 Open      High     Low   Close   Volume
# Date
# 2021-03-12  1,002.33  1,005.06  967.98  974.82  596,562
# 2021-03-10  1,007.80  1,009.96  989.18  994.44  498,398
# 2021-03-09  1,002.78  1,009.48  978.26  998.31  624,570
# 2021-03-08    989.79  1,016.91  988.86  998.43  750,096
# 2021-03-05    988.20  1,008.48  982.27  993.00  860,894

# %%
import pandas as pd

file_path = r'/content/combined_dataset.csv'

# Load the CSV file
df = pd.read_csv(file_path)

# Print the column names to debug
print("Column names in the CSV:", df.columns)
# Out:
# Column names in the CSV: Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
df.rename(columns=lambda x: x.strip(), inplace=True)

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.dtypes
# Out:
# Date      datetime64[ns]
# Open              object
# High              object
# Low               object
# Close             object
# Volume            object
# dtype: object

# %%
df.set_index('Date', inplace=True)
df.head()
# Out:
#                 Open      High     Low   Close   Volume
# Date
# 2021-03-12  1,002.33  1,005.06  967.98  974.82  596,562
# 2021-03-10  1,007.80  1,009.96  989.18  994.44  498,398
# 2021-03-09  1,002.78  1,009.48  978.26  998.31  624,570
# 2021-03-08    989.79  1,016.91  988.86  998.43  750,096
# 2021-03-05    988.20  1,008.48  982.27  993.00  860,894

# %%
import pandas as pd

# Load your dataset
df = pd.read_csv("/content/combined_dataset.csv")

# Convert numeric columns (except the Date column)
df[['Open', 'High', 'Low', 'Close', 'Volume']] = df[['Open', 'High', 'Low', 'Close', 'Volume']].replace(',', '', regex=True).astype(float)

# Pass the cleaned dataset to Gymnasium
env = gym.make("stocks-v0", df=df, window_size=10, frame_bound=(11, 100))

# %%
# Create the trading environment
env = gym.make('stocks-v0', df=df, frame_bound=(11, 100), window_size=10)

# %%
dir(env)
# Out:
# ['__annotations__',
#  '__class__',
#  '__class_getitem__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__orig_bases__',
#  '__parameters__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slots__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_action_space',
#  '_cached_spec',
#  '_disable_render_order_enforcing',
#  '_has_reset',
#  '_is_protocol',
#  '_metadata',
#  '_np_random',
#  '_np_random_seed',
#  '_observation_space',
#  '_saved_kwargs',
#  'action_space',
#  'class_name',
#  'close',
#  'env',
#  'get_wrapper_attr',
#  'has_reset',
#  'has_wrapper_attr',
#  'metadata',
#  'np_random',
#  'np_random_seed',
#  'observation_space',
#  'render',
#  'render_mode',
#  'reset',
#  'set_wrapper_attr',
#  'spec',
#  'step',
#  'unwrapped',
#  'wrapper_spec']

# %%
env.action_space
# Out:
# Discrete(2)

# %%
import numpy as np
import pandas as pd
import gymnasium as gym
import gym_anytrading

# Load Data
df = pd.read_csv(r"/content/combined_dataset.csv")
df.columns = df.columns.str.strip()

# Convert Date column to datetime
df['Date'] = pd.to_datetime(df['Date'], format='%m/%d/%Y')

# Ensure numerical columns are float
numeric_cols = ["Open", "High", "Low", "Close", "Volume"]
df[numeric_cols] = df[numeric_cols].replace({",": ""}, regex=True).astype(float)

# Sort data by Date
df = df.sort_values(by='Date').reset_index(drop=True)

# Set frame_bound
frame_start = 11
frame_end = min(500, len(df))

# Debug: Check the subset
sub_df = df.iloc[frame_start:frame_end].copy()
print("Sub DataFrame Shape:", sub_df.shape)

# Create Environment
env = gym.make('stocks-v0', df=sub_df, frame_bound=(frame_start, frame_end), window_size=10)
# Out:
# Sub DataFrame Shape: (489, 6)

# %%
print(dir(env))
print(env.metadata)
# Out:
# ['__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__enter__', '__eq__', '__exit__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_action_space', '_cached_spec', '_disable_render_order_enforcing', '_has_reset', '_is_protocol', '_metadata', '_np_random', '_np_random_seed', '_observation_space', '_saved_kwargs', 'action_space', 'class_name', 'close', 'env', 'get_wrapper_attr', 'has_reset', 'has_wrapper_attr', 'metadata', 'np_random', 'np_random_seed', 'observation_space', 'render', 'render_mode', 'reset', 'set_wrapper_attr', 'spec', 'step', 'unwrapped', 'wrapper_spec']
# {'render_modes': ['human'], 'render_fps': 3}

# %%
from stable_baselines3.common.vec_env import DummyVecEnv
import gymnasium as gym

# Define the environment maker
def env_maker():
    return gym.make('stocks-v0', df=df, frame_bound=(11, 100), window_size=10)

# Create a vectorized environment
env = DummyVecEnv([env_maker])

# Interact with the environment
obs = env.reset()

while True:
    action = [env.action_space.sample()]
    result = env.step(action)

    # Check the number of values returned
    if len(result) == 5:  # Newer API with `truncated`
        obs, rewards, dones, truncateds, infos = result
        done_flag = dones[0] or truncateds[0]
    elif len(result) == 4:  # Older API without `truncated`
        obs, rewards, dones, infos = result
        done_flag = dones[0]
    else:
        raise ValueError("Unexpected return format from env.step(action)")

    if done_flag:
        print("Episode finished")
        break

env.close()
# Out:
# Episode finished

# %%
pip install stable-baselines3[extra] sb3-contrib
# Out:
# Collecting sb3-contrib
#   Downloading sb3_contrib-2.6.0-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: stable-baselines3[extra] in /usr/local/lib/python3.11/dist-packages (2.6.0)
# Requirement already satisfied: gymnasium<1.2.0,>=0.29.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (1.1.1)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.0.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.6.0+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (3.10.0)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (4.11.0.86)
# Requirement already satisfied: pygame in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.6.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (5.9.5)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (13.9.4)
# Requirement already satisfied: ale-py>=0.9.0 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (0.10.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.11/dist-packages (from stable-baselines3[extra]) (11.1.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3[extra]) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium<1.2.0,>=0.29.1->stable-baselines3[extra]) (0.0.4)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.71.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.7)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (5.29.4)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (75.1.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (3.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.18.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable-baselines3[extra]) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable-baselines3[extra]) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3[extra]) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3[extra]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3[extra]) (2025.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (3.0.2)
# Downloading sb3_contrib-2.6.0-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.8/92.8 kB 2.2 MB/s eta 0:00:00
# Installing collected packages: sb3-contrib
# Successfully installed sb3-contrib-2.6.0

# %%
from stable_baselines3 import DQN

model = DQN(
    "MlpPolicy",
    env,
    learning_rate=5e-5,
    batch_size=128,
    exploration_fraction=0.05,
    exploration_final_eps=0.01,
    target_update_interval=1000,
    verbose=1
)
model.learn(total_timesteps=150000)
# Out:
# Streaming output truncated to the last 5000 lines.
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.94     |
# |    n_updates        | 8158     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 376      |
# |    fps              | 831      |
# |    time_elapsed     | 39       |
# |    total_timesteps  | 33088    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 7.68     |
# |    n_updates        | 8246     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 380      |
# |    fps              | 833      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 33440    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.57     |
# |    n_updates        | 8334     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 232      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 384      |
# |    fps              | 834      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 33792    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.13     |
# |    n_updates        | 8422     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 388      |
# |    fps              | 835      |
# |    time_elapsed     | 40       |
# |    total_timesteps  | 34144    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.67     |
# |    n_updates        | 8510     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 392      |
# |    fps              | 836      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 34496    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.8      |
# |    n_updates        | 8598     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 396      |
# |    fps              | 836      |
# |    time_elapsed     | 41       |
# |    total_timesteps  | 34848    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.13     |
# |    n_updates        | 8686     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 400      |
# |    fps              | 837      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 35200    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.45     |
# |    n_updates        | 8774     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 404      |
# |    fps              | 838      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 35552    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.42     |
# |    n_updates        | 8862     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 236      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 408      |
# |    fps              | 839      |
# |    time_elapsed     | 42       |
# |    total_timesteps  | 35904    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.49     |
# |    n_updates        | 8950     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 239      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 412      |
# |    fps              | 840      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 36256    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.9      |
# |    n_updates        | 9038     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 238      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 416      |
# |    fps              | 840      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 36608    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.93     |
# |    n_updates        | 9126     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 420      |
# |    fps              | 840      |
# |    time_elapsed     | 43       |
# |    total_timesteps  | 36960    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.35     |
# |    n_updates        | 9214     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 424      |
# |    fps              | 841      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 37312    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.21     |
# |    n_updates        | 9302     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 428      |
# |    fps              | 842      |
# |    time_elapsed     | 44       |
# |    total_timesteps  | 37664    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.84     |
# |    n_updates        | 9390     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 432      |
# |    fps              | 843      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 38016    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.87     |
# |    n_updates        | 9478     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 234      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 436      |
# |    fps              | 843      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 38368    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.26     |
# |    n_updates        | 9566     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 440      |
# |    fps              | 844      |
# |    time_elapsed     | 45       |
# |    total_timesteps  | 38720    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.53     |
# |    n_updates        | 9654     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 235      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 444      |
# |    fps              | 845      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 39072    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.99     |
# |    n_updates        | 9742     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 233      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 448      |
# |    fps              | 846      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 39424    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.43     |
# |    n_updates        | 9830     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 231      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 452      |
# |    fps              | 847      |
# |    time_elapsed     | 46       |
# |    total_timesteps  | 39776    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.59     |
# |    n_updates        | 9918     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 229      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 456      |
# |    fps              | 848      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 40128    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.54     |
# |    n_updates        | 10006    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 225      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 460      |
# |    fps              | 849      |
# |    time_elapsed     | 47       |
# |    total_timesteps  | 40480    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.31     |
# |    n_updates        | 10094    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 219      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 464      |
# |    fps              | 849      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 40832    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.17     |
# |    n_updates        | 10182    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 468      |
# |    fps              | 850      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 41184    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.41     |
# |    n_updates        | 10270    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 472      |
# |    fps              | 848      |
# |    time_elapsed     | 48       |
# |    total_timesteps  | 41536    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.37     |
# |    n_updates        | 10358    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 218      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 476      |
# |    fps              | 846      |
# |    time_elapsed     | 49       |
# |    total_timesteps  | 41888    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.6      |
# |    n_updates        | 10446    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 217      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 480      |
# |    fps              | 844      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 42240    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.75     |
# |    n_updates        | 10534    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 484      |
# |    fps              | 842      |
# |    time_elapsed     | 50       |
# |    total_timesteps  | 42592    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.23     |
# |    n_updates        | 10622    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 214      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 488      |
# |    fps              | 840      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 42944    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 7.94     |
# |    n_updates        | 10710    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 214      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 492      |
# |    fps              | 841      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 43296    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 1.77     |
# |    n_updates        | 10798    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 212      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 496      |
# |    fps              | 841      |
# |    time_elapsed     | 51       |
# |    total_timesteps  | 43648    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.9      |
# |    n_updates        | 10886    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 210      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 500      |
# |    fps              | 842      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 44000    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.05     |
# |    n_updates        | 10974    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 210      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 504      |
# |    fps              | 843      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 44352    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.66     |
# |    n_updates        | 11062    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 508      |
# |    fps              | 843      |
# |    time_elapsed     | 52       |
# |    total_timesteps  | 44704    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.79     |
# |    n_updates        | 11150    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 205      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 512      |
# |    fps              | 844      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 45056    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.75     |
# |    n_updates        | 11238    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 516      |
# |    fps              | 845      |
# |    time_elapsed     | 53       |
# |    total_timesteps  | 45408    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.51     |
# |    n_updates        | 11326    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 520      |
# |    fps              | 845      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 45760    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.31     |
# |    n_updates        | 11414    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 209      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 524      |
# |    fps              | 846      |
# |    time_elapsed     | 54       |
# |    total_timesteps  | 46112    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.51     |
# |    n_updates        | 11502    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 210      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 528      |
# |    fps              | 843      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 46464    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.57     |
# |    n_updates        | 11590    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 209      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 532      |
# |    fps              | 844      |
# |    time_elapsed     | 55       |
# |    total_timesteps  | 46816    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.47     |
# |    n_updates        | 11678    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 207      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 536      |
# |    fps              | 840      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 47168    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.04     |
# |    n_updates        | 11766    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 205      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 540      |
# |    fps              | 841      |
# |    time_elapsed     | 56       |
# |    total_timesteps  | 47520    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.89     |
# |    n_updates        | 11854    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 206      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 544      |
# |    fps              | 838      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 47872    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.7      |
# |    n_updates        | 11942    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 205      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 548      |
# |    fps              | 838      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 48224    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.16     |
# |    n_updates        | 12030    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 206      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 552      |
# |    fps              | 839      |
# |    time_elapsed     | 57       |
# |    total_timesteps  | 48576    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 2.87     |
# |    n_updates        | 12118    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 206      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 556      |
# |    fps              | 839      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 48928    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.11     |
# |    n_updates        | 12206    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 206      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 560      |
# |    fps              | 840      |
# |    time_elapsed     | 58       |
# |    total_timesteps  | 49280    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.12     |
# |    n_updates        | 12294    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 564      |
# |    fps              | 840      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 49632    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.83     |
# |    n_updates        | 12382    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 209      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 568      |
# |    fps              | 841      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 49984    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 2.41     |
# |    n_updates        | 12470    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 209      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 572      |
# |    fps              | 841      |
# |    time_elapsed     | 59       |
# |    total_timesteps  | 50336    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.73     |
# |    n_updates        | 12558    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 209      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 576      |
# |    fps              | 842      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 50688    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.94     |
# |    n_updates        | 12646    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 210      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 580      |
# |    fps              | 842      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 51040    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.18     |
# |    n_updates        | 12734    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 212      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 584      |
# |    fps              | 843      |
# |    time_elapsed     | 60       |
# |    total_timesteps  | 51392    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.19     |
# |    n_updates        | 12822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 214      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 588      |
# |    fps              | 841      |
# |    time_elapsed     | 61       |
# |    total_timesteps  | 51744    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.74     |
# |    n_updates        | 12910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 214      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 592      |
# |    fps              | 839      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 52096    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.18     |
# |    n_updates        | 12998    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 213      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 596      |
# |    fps              | 838      |
# |    time_elapsed     | 62       |
# |    total_timesteps  | 52448    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.11     |
# |    n_updates        | 13086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 600      |
# |    fps              | 835      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 52800    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.61     |
# |    n_updates        | 13174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 604      |
# |    fps              | 834      |
# |    time_elapsed     | 63       |
# |    total_timesteps  | 53152    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.44     |
# |    n_updates        | 13262    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 608      |
# |    fps              | 835      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 53504    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.92     |
# |    n_updates        | 13350    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 216      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 612      |
# |    fps              | 835      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 53856    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.87     |
# |    n_updates        | 13438    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 616      |
# |    fps              | 836      |
# |    time_elapsed     | 64       |
# |    total_timesteps  | 54208    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.86     |
# |    n_updates        | 13526    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 215      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 620      |
# |    fps              | 836      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 54560    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 2.6      |
# |    n_updates        | 13614    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 213      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 624      |
# |    fps              | 836      |
# |    time_elapsed     | 65       |
# |    total_timesteps  | 54912    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.78     |
# |    n_updates        | 13702    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 212      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 628      |
# |    fps              | 836      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 55264    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.25     |
# |    n_updates        | 13790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 212      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 632      |
# |    fps              | 836      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 55616    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.59     |
# |    n_updates        | 13878    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 211      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 636      |
# |    fps              | 837      |
# |    time_elapsed     | 66       |
# |    total_timesteps  | 55968    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.58     |
# |    n_updates        | 13966    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 212      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 640      |
# |    fps              | 838      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 56320    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.84     |
# |    n_updates        | 14054    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 209      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 644      |
# |    fps              | 838      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 56672    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.6      |
# |    n_updates        | 14142    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 212      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 648      |
# |    fps              | 839      |
# |    time_elapsed     | 67       |
# |    total_timesteps  | 57024    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.16     |
# |    n_updates        | 14230    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 212      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 652      |
# |    fps              | 839      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 57376    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.32     |
# |    n_updates        | 14318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 212      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 656      |
# |    fps              | 839      |
# |    time_elapsed     | 68       |
# |    total_timesteps  | 57728    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.76     |
# |    n_updates        | 14406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 214      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 660      |
# |    fps              | 840      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 58080    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.16     |
# |    n_updates        | 14494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 212      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 664      |
# |    fps              | 840      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 58432    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.71     |
# |    n_updates        | 14582    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 211      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 668      |
# |    fps              | 841      |
# |    time_elapsed     | 69       |
# |    total_timesteps  | 58784    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.85     |
# |    n_updates        | 14670    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 211      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 672      |
# |    fps              | 841      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 59136    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.27     |
# |    n_updates        | 14758    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 211      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 676      |
# |    fps              | 842      |
# |    time_elapsed     | 70       |
# |    total_timesteps  | 59488    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.96     |
# |    n_updates        | 14846    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 209      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 680      |
# |    fps              | 842      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 59840    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.81     |
# |    n_updates        | 14934    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 684      |
# |    fps              | 843      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 60192    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.23     |
# |    n_updates        | 15022    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 207      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 688      |
# |    fps              | 843      |
# |    time_elapsed     | 71       |
# |    total_timesteps  | 60544    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.73     |
# |    n_updates        | 15110    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 207      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 692      |
# |    fps              | 844      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 60896    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.77     |
# |    n_updates        | 15198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 208      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 696      |
# |    fps              | 844      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 61248    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.27     |
# |    n_updates        | 15286    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 207      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 700      |
# |    fps              | 845      |
# |    time_elapsed     | 72       |
# |    total_timesteps  | 61600    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.38     |
# |    n_updates        | 15374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 206      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 704      |
# |    fps              | 845      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 61952    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 3.95     |
# |    n_updates        | 15462    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 205      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 708      |
# |    fps              | 844      |
# |    time_elapsed     | 73       |
# |    total_timesteps  | 62304    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.95     |
# |    n_updates        | 15550    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 205      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 712      |
# |    fps              | 843      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 62656    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.16     |
# |    n_updates        | 15638    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 204      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 716      |
# |    fps              | 842      |
# |    time_elapsed     | 74       |
# |    total_timesteps  | 63008    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.93     |
# |    n_updates        | 15726    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 201      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 720      |
# |    fps              | 840      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 63360    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.4      |
# |    n_updates        | 15814    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 202      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 724      |
# |    fps              | 839      |
# |    time_elapsed     | 75       |
# |    total_timesteps  | 63712    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.95     |
# |    n_updates        | 15902    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 203      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 728      |
# |    fps              | 839      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 64064    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.85     |
# |    n_updates        | 15990    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 201      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 732      |
# |    fps              | 840      |
# |    time_elapsed     | 76       |
# |    total_timesteps  | 64416    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.91     |
# |    n_updates        | 16078    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 203      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 736      |
# |    fps              | 840      |
# |    time_elapsed     | 77       |
# |    total_timesteps  | 64768    |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.26     |
# |    n_updates        | 16166    |
# ...
# |    time_elapsed     | 164      |
# |    total_timesteps  | 139392   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.27     |
# |    n_updates        | 34822    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 254      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1588     |
# |    fps              | 849      |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 139744   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.81     |
# |    n_updates        | 34910    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 256      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1592     |
# |    fps              | 849      |
# |    time_elapsed     | 164      |
# |    total_timesteps  | 140096   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.23     |
# |    n_updates        | 34998    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 256      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1596     |
# |    fps              | 849      |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 140448   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.28     |
# |    n_updates        | 35086    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 256      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1600     |
# |    fps              | 849      |
# |    time_elapsed     | 165      |
# |    total_timesteps  | 140800   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.19     |
# |    n_updates        | 35174    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 255      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1604     |
# |    fps              | 849      |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 141152   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 7.14     |
# |    n_updates        | 35262    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 254      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1608     |
# |    fps              | 850      |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 141504   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.19     |
# |    n_updates        | 35350    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 254      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1612     |
# |    fps              | 850      |
# |    time_elapsed     | 166      |
# |    total_timesteps  | 141856   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.63     |
# |    n_updates        | 35438    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 255      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1616     |
# |    fps              | 850      |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 142208   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.55     |
# |    n_updates        | 35526    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 255      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1620     |
# |    fps              | 850      |
# |    time_elapsed     | 167      |
# |    total_timesteps  | 142560   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.78     |
# |    n_updates        | 35614    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 255      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1624     |
# |    fps              | 850      |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 142912   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.6      |
# |    n_updates        | 35702    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 254      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1628     |
# |    fps              | 850      |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 143264   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.48     |
# |    n_updates        | 35790    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 255      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1632     |
# |    fps              | 850      |
# |    time_elapsed     | 168      |
# |    total_timesteps  | 143616   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.94     |
# |    n_updates        | 35878    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 255      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1636     |
# |    fps              | 850      |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 143968   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.11     |
# |    n_updates        | 35966    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 255      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1640     |
# |    fps              | 850      |
# |    time_elapsed     | 169      |
# |    total_timesteps  | 144320   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.3      |
# |    n_updates        | 36054    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 254      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1644     |
# |    fps              | 850      |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 144672   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.35     |
# |    n_updates        | 36142    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 254      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1648     |
# |    fps              | 851      |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 145024   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.97     |
# |    n_updates        | 36230    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 256      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1652     |
# |    fps              | 851      |
# |    time_elapsed     | 170      |
# |    total_timesteps  | 145376   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.77     |
# |    n_updates        | 36318    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 256      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1656     |
# |    fps              | 851      |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 145728   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.12     |
# |    n_updates        | 36406    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 256      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1660     |
# |    fps              | 851      |
# |    time_elapsed     | 171      |
# |    total_timesteps  | 146080   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.69     |
# |    n_updates        | 36494    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 257      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1664     |
# |    fps              | 851      |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 146432   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.32     |
# |    n_updates        | 36582    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 258      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1668     |
# |    fps              | 851      |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 146784   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.19     |
# |    n_updates        | 36670    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 260      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1672     |
# |    fps              | 851      |
# |    time_elapsed     | 172      |
# |    total_timesteps  | 147136   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.44     |
# |    n_updates        | 36758    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 260      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1676     |
# |    fps              | 850      |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 147488   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.27     |
# |    n_updates        | 36846    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 260      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1680     |
# |    fps              | 850      |
# |    time_elapsed     | 173      |
# |    total_timesteps  | 147840   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.31     |
# |    n_updates        | 36934    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 259      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1684     |
# |    fps              | 849      |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 148192   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.35     |
# |    n_updates        | 37022    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 259      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1688     |
# |    fps              | 849      |
# |    time_elapsed     | 174      |
# |    total_timesteps  | 148544   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 4.9      |
# |    n_updates        | 37110    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 259      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1692     |
# |    fps              | 848      |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 148896   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.74     |
# |    n_updates        | 37198    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 258      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1696     |
# |    fps              | 848      |
# |    time_elapsed     | 175      |
# |    total_timesteps  | 149248   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 5.56     |
# |    n_updates        | 37286    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 259      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1700     |
# |    fps              | 848      |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 149600   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.08     |
# |    n_updates        | 37374    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    ep_len_mean      | 88       |
# |    ep_rew_mean      | 260      |
# |    exploration_rate | 0.01     |
# | time/               |          |
# |    episodes         | 1704     |
# |    fps              | 848      |
# |    time_elapsed     | 176      |
# |    total_timesteps  | 149952   |
# | train/              |          |
# |    learning_rate    | 5e-05    |
# |    loss             | 6.01     |
# |    n_updates        | 37462    |
# ----------------------------------

# %%
result = env.reset()
if isinstance(result, tuple):
    obs, info = result
else:
    obs = result
    info = None

# %%
pip uninstall gym -y
# Out:
# WARNING: Skipping gym as it is not installed.

# %%
df.columns = df.columns.str.strip()

# %%
import numpy as np
import gymnasium as gym
import gym_anytrading  # Ensure this is installed

# Convert df to float32


# Create the environment
env = gym.make('stocks-v0', df=df, frame_bound=(11, 100), window_size=10)

# Reset the environment
obs, info = env.reset()

while True:
    # Ensure the correct observation shape (5, 2)
    obs = obs.reshape((10, 2))

    # Ensure model is trained before predicting
    if model is None:
        raise ValueError("The model is not trained! Train it before running this script.")

    # Predict the action (assuming model is a trained agent)
    action, _states = model.predict(obs)

    # Take a step in the environment
    obs, rewards, done, truncated, info = env.step(action)

    # Check if the episode has ended
    if done or truncated:
        print("Final Info:", info)
        break
# Out:
# Final Info: {'total_reward': np.float32(293.13), 'total_profit': np.float32(1.0813097), 'position': <Positions.Long: 1>}

# %%
print(df.columns)
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %%
# Run the agent in the environment
obs, info = env.reset()

while True:
    obs = obs.reshape((10, 2))
    action, _states = model.predict(obs)
    obs, rewards, done, truncated, info = env.step(action)

    if done or truncated:
        print("Final Info:", info)
        break

# ✅ Render AFTER trading, WITHOUT resetting the environment
plt.figure(figsize=(15,6))
plt.cla()
env.render()  # This will now show the actual trades
plt.show()
# Out:
# Final Info: {'total_reward': np.float32(296.76), 'total_profit': np.float32(1.0858153), 'position': <Positions.Long: 1>}

# %%
model.save("dqn.zip")

# %%
from google.colab import files
files.download("dqn.zip")
